# %%
# Import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load CSV files into DataFrames
df = pd.read_csv('./data/AAs.csv')
df.head()
# Out:
#    name       Asp       Pro       Met       Phe       Val       Cys  Glu  \
# 0  RC01  0.086500  0.578000  0.059233  0.161333  0.300667  0.064033  0.0
# 1  RC02  0.092967  0.573667  0.061100  0.149000  0.302667  0.064667  0.0
# 2  RC03  0.099233  0.586333  0.058533  0.170667  0.317333  0.064500  0.0
# 3  RC04  0.116900  0.605667  0.063500  0.193000  0.359667  0.063667  0.0
# 4  RC05  0.146333  0.621333  0.067467  0.244333  0.310333  0.068967  0.0
#
#         His  Gly  ...       Ile       Leu       Thr       Arg       Ser  \
# 0  0.015400  0.0  ...  0.089433  0.107467  0.127967  0.425667  0.159367
# 1  0.021800  0.0  ...  0.084333  0.101967  0.131333  0.429333  0.156333
# 2  0.026700  0.0  ...  0.093433  0.112333  0.144000  0.389333  0.252000
# 3  0.064967  0.0  ...  0.107100  0.128000  0.192333  0.437000  0.436667
# 4  0.022067  0.0  ...  0.102333  0.137333  0.180667  0.331667  0.181667
#
#         Tyr       Gln       Asn       Lys       Ala
# ...

# %%
sns.set(style="whitegrid")
# Assuming 'df' is already defined and processed
df['group'] = df['name'].str[:2]

df_melted = df.melt(id_vars=['name', 'group'], var_name='amino_acid', value_name='content')
df_melted = df_melted[df_melted['amino_acid'] != 'name']

# Create the plot
plt.figure(figsize=(7, 4))
sns.boxplot(data=df_melted, x='amino_acid', y='content', hue='group', showfliers=False)
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
# plt.savefig("amino_acid_boxplot.pdf", format="pdf")
plt.show()
